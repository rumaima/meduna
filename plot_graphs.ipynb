# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns 
sns.set_theme()

# %%
OUTPUT_DIR = "/home/umaima.rahman/research/sem6/LaFTer/"
fname = "output/LaFTer/vit_b32/shenzhen_cxr/log.txt-2024-04-06-00-42-20split_60_SGD_LOGURU.log"
fpath = OUTPUT_DIR+fname

# %%
data = pd.read_csv(fpath, sep='\t', header=None)


# Extract the last three columns
df = data.iloc[:, -3:]

# Rename the columns
df.columns = ['train', 'val', 'test']

# %%
plt.plot(df)
plt.legend(['train', 'val', 'test'], loc='upper left')
plt.xlabel('epoch')
plt.ylabel('Accuracy [%]')
# Out:
# Text(0, 0.5, 'Accuracy [%]')
