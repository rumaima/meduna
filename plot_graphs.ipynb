# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns 
sns.set_theme()

# %%
OUTPUT_DIR = "/home/umaima.rahman/research/sem6/LaFTer/"
fname_1batch = "output/LaFTer/vit_b32/shenzhen_cxr/log.txt-2024-04-06-02-47-49split_60_SGD_LOGURU.log"
fname_2trans = "output/LaFTer/vit_b32/shenzhen_cxr/log.txt-2024-04-06-02-38-58split_60_SGD_LOGURU.log"
shenzhen_ajeeb = "output/LaFTer/vit_b32/shenzhen_cxr/log.txt-2024-04-07-14-59-40semi_SGD_LOGURU.log"
shenzhen_log =  "output/LaFTer/vit_b32/shenzhen_cxr/log.txt-2024-04-07-15-05-22semi_SGD_LOGURU.log"
# "output/LaFTer/vit_b32/pneumonia_guangzhou/log.txt-2024-04-07-05-05-18semi_SGD_LOGURU.log"
# "output/LaFTer/vit_b32/montgomery_cxr/log.txt-2024-04-07-05-11-35semi_SGD_LOGURU.log"
# "output/LaFTer/vit_b32/covid/log.txt-2024-04-07-05-10-41semi_SGD_LOGURU.log"
fname_semi = "output/LaFTer/vit_b32/shenzhen_cxr/log.txt-2024-04-07-14-59-40semi_SGD_LOGURU.log"

fpath = OUTPUT_DIR+shenzhen_log

# %%
data = pd.read_csv(fpath, sep='\t', header=None)


# Extract the last three columns
df = data.iloc[:, -3:]

# Rename the columns
df.columns = ['train', 'val', 'test']

# %%
plt.plot(df, '-')
plt.legend(['train', 'val', 'test'], loc='upper left')
plt.xlabel('epoch')
plt.ylabel('Accuracy [%]')
# Out:
# Text(0, 0.5, 'Accuracy [%]')
