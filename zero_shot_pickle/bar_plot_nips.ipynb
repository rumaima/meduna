# %%
import pandas as pd
import numpy as np
import seaborn as sns
import sys
from pathlib import Path
from matplotlib import pyplot as plt
import matplotlib.font_manager as font_manager

# %% [markdown]
# Class Name		Number of Occurances in Training				mAP	Recall
#  Cassette deck		0				55.66	97.29
# Lynx		0				94.88	100.00
#  Humidifier		1				95.38	100.00
# Armadillo		3				78.69	100.00
# Shellfish		3				53.19	94.64
# Cooking spray		4				69.20	100.00
#  Hedgehog		4				92.00	97.61
# Centipede		5				73.82	97.50
# Oboe		5				12.78	85.19
# Balancing beam		40				3.47	40.67

# %%
ap = [25.46, 28.60,0, 28.15, 34.74, 36.51, 37.95,0, 32.09, 36.31, 37.01, 37.35, 0,38.77]

# %%
classnames = ["100", "300","","10", "30", "50", "100", "","10", "30", "50", "100", "","200"]
num_occ = ["0","0","1","3","3","4","4","5","5","","84K","119K","121K","142K"]
y = np.array(ap)
x = np.array(classnames)
x.shape, y.shape, len(num_occ)
# Out:
# ((14,), (14,), 14)

# %%
ind = np.arange(0,3.4,0.25)
ind.shape, ind
# Out:
# ((14,),
#  array([0.  , 0.25, 0.5 , 0.75, 1.  , 1.25, 1.5 , 1.75, 2.  , 2.25, 2.5 ,
#         2.75, 3.  , 3.25]))

# %%
fig=plt.figure(figsize=(5.5,2.1),dpi=250)
ax=fig.add_subplot(111)

c = ["tab:blue","sandybrown","white","teal","orangered","tab:purple","tomato","white","slategrey",
     "c","plum","teal","plum","yellowgreen"]


bars = ax.bar(ind,y, width=0.25, alpha=0.73, color=c, label="s", ecolor='black', capsize=1)
patterns = ('//','o',"", '//','o',".",'xx', "",'//','o',".",'xx',"",'//')

for bar, pattern in zip(bars, patterns):
    bar.set_hatch(pattern)
    
plt.ylim((20,42))
plt.xlim((-0.3,3.5))
ax.set_xticks(ind)
ax.set_xticklabels(classnames, fontsize=9.5, fontweight='bold',rotation = '0')
ax.set_ylabel("AP", fontsize=12, fontweight='bold')

ax.set_axisbelow(True)
plt.grid(b=True, which='major', color='gray', linestyle='-', alpha=0.3)
plt.grid(b=True, which='minor', color='gray', linestyle='--', alpha=0.1)
plt.minorticks_on()

fig.savefig('graph_4.png', dpi=250, facecolor='auto', edgecolor='auto',
        orientation='portrait', format="png",
        transparent=False, bbox_inches='tight', pad_inches=0.05)
# Out:
# <ipython-input-10-4b025b07a820>:21: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   plt.grid(b=True, which='major', color='gray', linestyle='-', alpha=0.3)
# <ipython-input-10-4b025b07a820>:22: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   plt.grid(b=True, which='minor', color='gray', linestyle='--', alpha=0.1)

# %%
# Now plotting for the per-class analysis

# %%
classes_where_MmCoOp_is_better = [100.00,
68.09,
54.46,
41.18,
21.00] 
classes_where_MmCoOp_is_better.reverse()
classes_where_results_are_comparable = [0,
4.255319149,
16.83168317,
27.45098039,
65]
classes_where_results_are_comparable.reverse()

# %%
classnames = ["Caltech \n(generic objects)", "Oxford Flowers (Finegrain)", "UCF (Action recognition)", "DTD (Texture Classification)", "Eurosat (Sattelite images)"]

# %%
# classnames = ["100", "300","","10", "30", "50", "100", "","10", "30", "50", "100", "","200"]
num_occ = ["0","0","1","3","3"]
y = np.array(classes_where_MmCoOp_is_better)
x = np.array(classnames)
x.shape, y.shape, len(num_occ)
# Out:
# ((5,), (5,), 5)

# %%
ind = np.arange(0,3.4,0.25)
ind.shape, ind
# Out:
# ((14,),
#  array([0.  , 0.25, 0.5 , 0.75, 1.  , 1.25, 1.5 , 1.75, 2.  , 2.25, 2.5 ,
#         2.75, 3.  , 3.25]))

# %%
fig=plt.figure(figsize=(26,10),dpi=250)
ax=fig.add_subplot(111)

c = ["tab:blue","sandybrown","white","teal","orangered"]
x = np.arange(len(classnames))#set a width for each bar 
width = 0.3#create out first bar

bars = ax.bar(x - width/2,y, width=0.25, alpha=0.73, color=c, label="s", ecolor='black', capsize=1)
patterns = ('//','//','//','//')

for bar, pattern in zip(bars, patterns):
    bar.set_hatch(pattern)
    
plt.ylim((20,42))
plt.xlim((-0.3,3.5))
# ax.set_xticks(ind)
ax.set_xticklabels(classnames, fontsize=9.5, fontweight='bold',rotation = '0')
ax.set_ylabel("AP", fontsize=12, fontweight='bold')

ax.set_axisbelow(True)
plt.grid(b=True, which='major', color='gray', linestyle='-', alpha=0.3)
plt.grid(b=True, which='minor', color='gray', linestyle='--', alpha=0.1)
plt.minorticks_on()

# fig.savefig('graph_4.png', dpi=250, facecolor='auto', edgecolor='auto',
#         orientation='portrait', format="png",
#         transparent=False, bbox_inches='tight', pad_inches=0.05)
# Out:
# <ipython-input-16-8ccc17ca5669>:17: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(classnames, fontsize=9.5, fontweight='bold',rotation = '0')
# <ipython-input-16-8ccc17ca5669>:21: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   plt.grid(b=True, which='major', color='gray', linestyle='-', alpha=0.3)
# <ipython-input-16-8ccc17ca5669>:22: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   plt.grid(b=True, which='minor', color='gray', linestyle='--', alpha=0.1)

# %%
# Creating graph for per-class analysis
classes_where_MmCoOp_is_better = [100.00,
68.09,
54.46,
41.18,
21.00] 
classes_where_MmCoOp_is_better.reverse()
classes_where_results_are_comparable = [0,
4.255319149,
16.83168317,
27.45098039,
65]
classes_where_results_are_comparable.reverse()

# %%
labels = ["Caltech \n(generic objects)", "Oxford Flowers (Finegrain)", "UCF (Action recognition)", "DTD (Texture Classification)", "Eurosat (Sattelite images)"]

# %%
#create the dictionary of voting returns
data_dict = {"dataset_names": labels,
            '% classes: MmCoOp is better than CoCoOp': classes_where_MmCoOp_is_better,
            '% classes: MmCoOp is comparable with CoCoOp': classes_where_results_are_comparable}#convert that into a dataframe
data_df = pd.DataFrame(data_dict)#show the dictionary
data_df
# Out:
#                   dataset_names  % classes: MmCoOp is better than CoCoOp  \
# 0   Caltech \n(generic objects)                                    21.00
# 1    Oxford Flowers (Finegrain)                                    41.18
# 2      UCF (Action recognition)                                    54.46
# 3  DTD (Texture Classification)                                    68.09
# 4    Eurosat (Sattelite images)                                   100.00
#
#    % classes: MmCoOp is comparable with CoCoOp
# 0                                    65.000000
# 1                                    27.450980
# 2                                    16.831683
# 3                                     4.255319
# 4                                     0.000000

# %%
#use fivethirty eights style of plots
# plt.style.use("fivethirtyeight")#create the base axis to add the bars to
fig, ax = plt.subplots(1,1, figsize = (10,6))#extract the labels
label = data_df["dataset_names"]
#use this to create x ticks to add the data to
x = np.arange(len(label))#set a width for each bar 
width = 0.8#create out first bar
#set it so that x will be the centre of the bars
#so that we can add our labels later
#so set the centre of the first to be 1/2 width away
#to the left
label = ["Caltech\n(generic objects)", "Oxford Flowers\n(Finegrain)", "UCF\n(Action recognition)", "DTD\n(Texture Classification)","Eurosat\n(Sattelite images)"]
c = ["tab:blue","sandybrown","white","teal","orangered","tab:purple","tomato","white","slategrey",
     "c","plum","teal","plum","yellowgreen"]
c = ["tab:blue", "sandybrown", "white", "green", "tab:purple"]
rect1 = ax.bar(x,
              data_df['% classes: MmCoOp is better than CoCoOp'],
              width = width, alpha=0.73, color="cadetblue",
               label = '% classes: MmCoOp is better than CoCoOp',
               edgecolor = "black", align="center"
              )#create the second bar
ax.set_xticks(x)
#with a centre half a width to the right
# rect2 = ax.bar(x + width/2,
#               data_df['% classes: MmCoOp is comparable with CoCoOp'],
#               width = width,
#               label = '% classes: MmCoOp is comparable with CoCoOp',
#               edgecolor = "black")#add the labels to the axis
patterns = ('/','//','|','o', '+')
patterns = ('//', '//', '//', '//', '//')
for bar, pattern in zip(rect1, patterns):
    bar.set_hatch(pattern)
# for bar, pattern in zip(rect2, patterns):
#     bar.set_hatch(pattern)   
ax.set_ylabel("Performance %",
             fontsize = 17,
             labelpad = 0, weight='bold')
# ax.set_xlabel("Datasets",
#              fontsize = 24,
#              labelpad =20, weight='bold')
# ax.set_title("Votes per candidate",
#             fontsize = 30,
#             pad = 20)#set the ticks

label = ["Caltech\n(generic objects)", "Oxford Flowers\n(Finegrain)", "UCF\n(Action recognition)", "DTD\n(Texture Classification)","Eurosat\n(Sattelite images)"]
ax.set_xticklabels(label, weight='bold',fontsize = 13)#add the legend
plt.yticks(fontsize=12,  weight='bold')
#using the labels of the bars
# ax.legend(title = "",
#          fontsize = 28,
#          title_fontsize = 24)#adjust the tick paramaters
ax.set_axisbelow(True)
ax.grid(b=True, which='major', color='gray', linestyle='-', alpha=0.5)
ax.grid(b=True, which='minor', color='gray', linestyle='--', alpha=0.2)
plt.minorticks_on()
ax.tick_params(axis = "x",
              which = "both",
              labelrotation = 30,
              labelsize = 15)
ax.tick_params(axis = "y",
              which = "both",
              labelsize = 12)

# Add counts above the two bar graphs
for rect in rect1:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2.0, height, f'{height:.0f}' + '%', ha='center', va='bottom', weight='bold', fontsize=12)
# plt.savefig("graph3.png",dpi=500,bbox_inches='tight')
# Out:
# <ipython-input-24-57012c8e67cb>:53: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   ax.grid(b=True, which='major', color='gray', linestyle='-', alpha=0.5)
# <ipython-input-24-57012c8e67cb>:54: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   ax.grid(b=True, which='minor', color='gray', linestyle='--', alpha=0.2)

# %%
label#use fivethirty eights style of plots
# plt.style.use("fivethirtyeight")#create the base axis to add the bars to
fig, ax = plt.subplots(1,1, figsize = (10,6))#extract the labels
label = data_df["dataset_names"]
#use this to create x ticks to add the data to
x = np.arange(len(label))#set a width for each bar 
width = 0.7#create out first bar
#set it so that x will be the centre of the bars
#so that we can add our labels later
#so set the centre of the first to be 1/2 width away
#to the left
label = ["Caltech\n(generic objects)", "Oxford Flowers\n(Finegrain)", "UCF\n(Action recognition)", "DTD\n(Texture Classification)","Eurosat\n(Sattelite images)"]
c = ["tab:blue","sandybrown","white","teal","orangered","tab:purple","tomato","white","slategrey",
     "c","plum","teal","plum","yellowgreen"]
c = ["tab:blue", "sandybrown", "white", "green", "tab:purple"]
rect1 = ax.bar(x,
              data_df['% classes: MmCoOp is better than CoCoOp'],
              width = width, alpha=0.73, color="tab:blue",
               label = '% classes: MmCoOp is better than CoCoOp',
               edgecolor = "black", align="center"
              )#create the second bar
ax.set_xticks(x)
#with a centre half a width to the right
# rect2 = ax.bar(x + width/2,
#               data_df['% classes: MmCoOp is comparable with CoCoOp'],
#               width = width,
#               label = '% classes: MmCoOp is comparable with CoCoOp',
#               edgecolor = "black")#add the labels to the axis
patterns = ('/','//','|','o', '+')
patterns = ('//', '//', '//', '//', '//')
for bar, pattern in zip(rect1, patterns):
    bar.set_hatch(pattern)
# for bar, pattern in zip(rect2, patterns):
#     bar.set_hatch(pattern)   
ax.set_ylabel("% per-class performance",
             fontsize = 17,
             labelpad = 0, weight='bold')
ax.set_xlabel("Datasets",
             fontsize = 17,
             labelpad =20, weight='bold')
# ax.set_title("Votes per candidate",
#             fontsize = 30,
#             pad = 20)#set the ticks

label = ["Caltech", "Oxford Flowers", "UCF", "DTD","Eurosat"]
ax.set_xticklabels(label, weight='bold',fontsize = 13)#add the legend
plt.yticks(fontsize=12,  weight='bold')
#using the labels of the bars
# ax.legend(title = "",
#          fontsize = 28,
#          title_fontsize = 24)#adjust the tick paramaters
ax.set_axisbelow(True)
ax.grid(b=True, which='major', color='gray', linestyle='-', alpha=0.5)
ax.grid(b=True, which='minor', color='gray', linestyle='--', alpha=0.2)
plt.minorticks_on()
ax.tick_params(axis = "x",
              which = "both",
              labelrotation = 0,
              labelsize = 15)
ax.tick_params(axis = "y",
              which = "both",
              labelsize = 12)

# Add counts above the two bar graphs
for index, rect in enumerate(rect1):
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2.0, height, my_list[index], ha='center', va='bottom', fontsize=12, weight='bold')
plt.savefig("graph4.png",dpi=500,bbox_inches='tight')
# Out:
# <ipython-input-25-0a9e5c89a9d9>:53: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   ax.grid(b=True, which='major', color='gray', linestyle='-', alpha=0.5)
# <ipython-input-25-0a9e5c89a9d9>:54: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   ax.grid(b=True, which='minor', color='gray', linestyle='--', alpha=0.2)

# %%
label

# %%
my_list = ["Generic objects", "Finegrain", "Action\n recognition", "Texture\n Classification", "Sattelite images"]

# %%
# Plots for Rebuttal draw for the HM

datasetNames = ['Group A','Group B','Group C','Group D']
Ygirls = [10,20,20,40]
Zboys = [20,30,25,30]

# %%
# Plots for Rebuttal draw for the HM classes
plt.rc('text', usetex=True)
plt.rcParams['text.latex.preamble']=[r"\usepackage{amsmath}"]
datasetNames = ['ImageNet','Caltech101','OxfordPets','StanfordCars', 'Flowers102', 'Food101', 'FGVCAircraft', 'SUN397', 'DTD', 'EuroSAT', 'UCF101', 'Average over 11 datasets']
IVLP = [71.37, 95.68, 96.04, 75.28, 83.07, 89.83, 31.69, 78.43, 66.82, 79.74, 79.62, 77.51]
LSCL = [73.45 , 96.17, 96.19, 76.68, 86.17, 90.80, 38.67, 80.57, 70.96, 79.45, 83.25, 79.55]
GPA = [73.56, 96.29, 96.18, 76.42, 86.30, 91.02, 39.38, 80.66, 70.97, 80.02, 83.28, 79.70]
Diversity = [74.01, 96.02, 96.30, 76.58, 85.95, 91.10, 40.15, 80.52, 71.75, 82.32, 82.74, 79.97]
# Out:
# <ipython-input-150-285f056274dc>:3: MatplotlibDeprecationWarning: Support for setting an rcParam that expects a str value to a non-str value is deprecated since 3.5 and support will be removed two minor releases later.
#   plt.rcParams['text.latex.preamble']=[r"\usepackage{amsmath}"]

# %%
N = 4
c = ["tab:blue","sandybrown","white","teal","orangered","tab:purple","tomato","white","slategrey",
     "c","plum","teal","plum","yellowgreen"]
c = ["tab:blue", "sandybrown", "white", "green", "tab:purple"]
ind = np.arange(len(datasetNames[0:4])) 
width = 0.15
  
fig, ax = plt.subplots(1,1, figsize = (10,6))#extract the labels
label = data_df["dataset_names"]

ax.set_ylim([70, 99.20])


bar1 = ax.bar(ind, IVLP[0:4], width, color = c[0])
  

bar2 = ax.bar(ind+width, LSCL[0:4], width, color=c[1])
  

bar3 = ax.bar(ind+width*2, GPA[0:4], width, color = c[4])


bar4 = ax.bar(ind+width*3, Diversity[0:4], width, color = c[3])

patterns = ('/','//','|','o', '+')
patterns1 = ('|', '|', '|', '|', '|')
patterns2 = ('//', '//', '//', '//', '//')
patterns3 = ('o', 'o', 'o', 'o', 'o')
patterns4 = ('+', '+' ,'+' ,'+', '+')
for bar, pattern in zip(bar1, patterns1):
    bar.set_hatch(pattern)
for bar, pattern in zip(bar2, patterns2):
    bar.set_hatch(pattern)
for bar, pattern in zip(bar3, patterns3):
    bar.set_hatch(pattern)
for bar, pattern in zip(bar4, patterns4):
    bar.set_hatch(pattern)
    
ax.set_axisbelow(True)
ax.grid(b=True, which='major', color='gray', linestyle='-', alpha=0.5)
ax.grid(b=True, which='minor', color='gray', linestyle='--', alpha=0.2)
plt.minorticks_on()
ax.tick_params(axis = "x",
              which = "both",
              labelrotation = 0,
              labelsize = 15)
ax.tick_params(axis = "y",
              which = "both",
              labelsize = 12)

plt.xlabel("Datasets")
plt.ylabel('Harmonic Mean (%)')
# plt.title("Players Score")
  
plt.xticks(ind+width,datasetNames[0:4])
plt.legend( (bar1, bar2, bar3, bar4), ('IVLP', 'LSCL', 'GPA', 'Diversity') )
# plt.legend( (bar1, bar2, bar3, bar4), ('LSCL', 'GPA', 'Diversity') )
plt.show()
# Out:
# <ipython-input-151-c368861840e2>:40: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   ax.grid(b=True, which='major', color='gray', linestyle='-', alpha=0.5)
# <ipython-input-151-c368861840e2>:41: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   ax.grid(b=True, which='minor', color='gray', linestyle='--', alpha=0.2)

# %%
#create the dictionary of voting returns
data_dict = {"dataset_names": ['ImageNet','Caltech101','FGVC Aircrafts','EuroSAT', 'Average over 11 datasets'],
            '% classes: MmCoOp is better than CoCoOp': classes_where_MmCoOp_is_better,
            '% classes: MmCoOp is comparable with CoCoOp': classes_where_results_are_comparable}#convert that into a dataframe
data_df = pd.DataFrame(data_dict)#show the dictionary
data_df
# Out:
#               dataset_names  % classes: MmCoOp is better than CoCoOp  \
# 0                  ImageNet                                    21.00
# 1                Caltech101                                    41.18
# 2            FGVC Aircrafts                                    54.46
# 3                   EuroSAT                                    68.09
# 4  Average over 11 datasets                                   100.00
#
#    % classes: MmCoOp is comparable with CoCoOp
# 0                                    65.000000
# 1                                    27.450980
# 2                                    16.831683
# 3                                     4.255319
# 4                                     0.000000

# %%
fgvc eurosat imagenet caltech oxfordpets
# Out:
#   File "<ipython-input-153-094fffb34f02>", line 1
#     fgvc eurosat imagenet caltech oxfordpets
#          ^
# SyntaxError: invalid syntax

# %%
# Plots for Rebuttal draw for the HM classes

datasetNames = ['ImageNet','Caltech101','OxfordPets','StanfordCars', 'Flowers102', 'Food101', 'FGVCAircraft', 'SUN397', 'DTD', 'EuroSAT', 'UCF101', 'Average over 11 datasets']
IVLP = [66.50, 93.20, 97.20, 71.47, 72.10, 90.30, 25.23, 75.50, 56.20, 67.83, 74.17, 71.79]
LSCL = [69.77 , 94.37, 97.03, 74.60, 76.90, 91.23, 35.60, 78.70, 61.90, 69.30, 79.73, 75.38]
GPA = [70.03, 94.67, 97.10, 74.87, 77.10, 91.47, 36.83,78.83 , 62.00, 69.93, 79.80, 75.69]
Diversity = [70.73, 94.03, 97.30, 74.97, 76.50, 91.53, 37.87, 78.47, 62.97, 73.90,78.80 , 76.10]

# %%
# label#use fivethirty eights style of plots
# plt.style.use("fivethirtyeight")#create the base axis to add the bars to
fig, ax = plt.subplots(1,1, figsize = (6,5))#extract the labels
# label = data_df["dataset_names"]
#use this to create x ticks to add the data to
set_dataset_index = 3
x = np.arange(3) #set a width for each bar 
width = 0.5 #create out first bar
#set it so that x will be the centre of the bars
#so that we can add our labels later
#so set the centre of the first to be 1/2 width away
#to the left
x = np.arange(3) #set a width for each bar 
# label = ["Caltech\n(generic objects)", "Oxford Flowers\n(Finegrain)", "UCF\n(Action recognition)", "DTD\n(Texture Classification)","Eurosat\n(Sattelite images)"]
c = ["tab:blue","sandybrown","white","teal","orangered","tab:purple","tomato","white","slategrey",
     "c","plum","teal","plum","yellowgreen"]
c = ["tab:blue", "sandybrown", "white", "green", "tab:purple"]
rect1 = ax.bar(x,
              [LSCL[set_dataset_index], GPA[set_dataset_index], Diversity[set_dataset_index]],
              width = width, alpha=0.73, color="tab:blue",
               label = '% classes: MmCoOp is better than CoCoOp',
               edgecolor = "black", align="center"
              )#create the second bar
ax.set_xticks(x)

ax.set_ylim([LSCL[set_dataset_index] - 0.5,  Diversity[set_dataset_index] + 0.3])


#with a centre half a width to the right
# rect2 = ax.bar(x + width/2,
#               data_df['% classes: MmCoOp is comparable with CoCoOp'],
#               width = width,
#               label = '% classes: MmCoOp is comparable with CoCoOp',
#               edgecolor = "black")#add the labels to the axis
patterns = ('/','//','|','o', '+')
patterns = ('//', '//', '//', '//', '//')
for bar, pattern in zip(rect1, patterns):
    bar.set_hatch(pattern)
# for bar, pattern in zip(rect2, patterns):
#     bar.set_hatch(pattern)   
ax.set_ylabel("Novel class (%)",
             fontsize = 17,
             labelpad = 0, weight='bold')
ax.set_xlabel(datasetNames[set_dataset_index],
             fontsize = 17,
             labelpad =20, weight='bold')
# ax.set_title("Votes per candidate",
#             fontsize = 30,
#             pad = 20)#set the ticks

label = ["${\mathcal{L}_{SCL}}$", "GPA", "Text diversity"]
ax.set_xticklabels(label,fontsize = 13)#add the legend
plt.yticks(fontsize=12,  weight='bold')
#using the labels of the bars
# ax.legend(title = "",
#          fontsize = 28,
#          title_fontsize = 24)#adjust the tick paramaters
ax.set_axisbelow(True)
ax.grid(b=True, which='major', color='gray', linestyle='-', alpha=0.5)
ax.grid(b=True, which='minor', color='gray', linestyle='--', alpha=0.2)
plt.minorticks_on()
ax.tick_params(axis = "x",
              which = "both",
              labelrotation = 0,
              labelsize = 15)
ax.tick_params(axis = "y",
              which = "both",
              labelsize = 12)

# Add counts above the two bar graphs
# for index, rect in enumerate(rect1):
#     height = rect.get_height()
#     plt.text(rect.get_x() + rect.get_width() / 2.0, height, my_list[index], ha='center', va='bottom', fontsize=12, weight='bold')
# plt.savefig(f"graph_{datasetNames[set_dataset_index]}.png",dpi=500,bbox_inches='tight')
# Out:
# <ipython-input-5-2536005605a9>:59: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   ax.grid(b=True, which='major', color='gray', linestyle='-', alpha=0.5)
# <ipython-input-5-2536005605a9>:60: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   ax.grid(b=True, which='minor', color='gray', linestyle='--', alpha=0.2)

# %%
# New figure plotting...

# label#use fivethirty eights style of plots
# plt.style.use("fivethirtyeight")#create the base axis to add the bars to
fig, ax = plt.subplots(1,1, figsize = (6,5))#extract the labels
# label = data_df["dataset_names"]
#use this to create x ticks to add the data to
set_dataset_index = 5
x = np.arange(1) #set a width for each bar 
width = 0.2 #create out first bar
#set it so that x will be the centre of the bars
#so that we can add our labels later
#so set the centre of the first to be 1/2 width away
#to the left
x = np.arange(1) #set a width for each bar 
# label = ["Caltech\n(generic objects)", "Oxford Flowers\n(Finegrain)", "UCF\n(Action recognition)", "DTD\n(Texture Classification)","Eurosat\n(Sattelite images)"]
c = ["tab:blue","sandybrown","white","teal","orangered","tab:purple","tomato","white","slategrey",
     "c","plum","teal","plum","yellowgreen"]
c = ["tab:blue", "sandybrown", "white", "green", "tab:purple"]
rect1 = ax.bar(x,
              [LSCL[set_dataset_index]],
              width = width, alpha=0.73, color="tab:blue",
               label = '% classes: MmCoOp is better than CoCoOp',
               edgecolor = "black", align="center"
              )#create the second bar
rect2 = ax.bar(x + width*2,
              [GPA[set_dataset_index]],
              width = width, alpha=0.73, color="tab:purple",
               label = '% classes: MmCoOp is better than CoCoOp',
               edgecolor = "black", align="center"
              )#create the second bar

rect3 = ax.bar(x + width*4,
              [Diversity[set_dataset_index]],
              width = width, alpha=0.73, color="teal",
               label = '% classes: MmCoOp is better than CoCoOp',
               edgecolor = "black", align="center"
              )#create the second bar
# ax.set_xticks(x)

ax.set_ylim([LSCL[set_dataset_index] - 0.1,  Diversity[set_dataset_index] + 0.15])


#with a centre half a width to the right
# rect2 = ax.bar(x + width/2,
#               data_df['% classes: MmCoOp is comparable with CoCoOp'],
#               width = width,
#               label = '% classes: MmCoOp is comparable with CoCoOp',
#               edgecolor = "black")#add the labels to the axis
patterns = ('/','//','|','o', '+')
patterns = ('//', '//', '//', '//', '//')
patterns = ('/','//','|','o', '+')
patterns1 = ('|', '|', '|', '|', '|')
patterns2 = ('//', '//', '//', '//', '//')
patterns3 = ('o', 'o', 'o', 'o', 'o')
patterns4 = ('+', '+' ,'+' ,'+', '+')
for bar, pattern in zip(rect1, patterns1):
    bar.set_hatch(pattern)
for bar, pattern in zip(rect2, patterns2):
    bar.set_hatch(pattern)
for bar, pattern in zip(rect3, patterns3):
    bar.set_hatch(pattern)
# for bar, pattern in zip(rect2, patterns):
#     bar.set_hatch(pattern)   
ax.set_ylabel("Novel class (%)",
             fontsize = 17,
             labelpad = 0, weight='bold')
ax.set_xlabel(datasetNames[set_dataset_index],
             fontsize = 17,
             labelpad =20, weight='bold')
# ax.set_title("Votes per candidate",
#             fontsize = 30,
#             pad = 20)#set the ticks

# label = ["${\mathcal{L}_{SCL}}$", "GPA", "Text diversity"]
# ax.set_xticklabels(label,fontsize = 13)#add the legend
plt.yticks(fontsize=12,  weight='bold')
#using the labels of the bars
# ax.legend(title = "",
#          fontsize = 28,
#          title_fontsize = 24)#adjust the tick paramaters
ax.set_axisbelow(True)
ax.grid(b=True, which='major', color='gray', linestyle='-', alpha=0.5)
ax.grid(b=True, which='minor', color='gray', linestyle='--', alpha=0.2)
plt.minorticks_on()
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off
ax.tick_params(axis = "y",
              which = "both",
              labelsize = 12)
plt.legend((rect1, rect2, rect3), ('${\mathcal{L}_{SCL}}$', '${\mathcal{L}_{SCL}}$ + GPA', '${\mathcal{L}_{SCL}}$+ GPA + Div.') ,fontsize=15)
# Add counts above the two bar graphs
# for index, rect in enumerate(rect1):
#     height = rect.get_height()
#     plt.text(rect.get_x() + rect.get_width() / 2.0, height, my_list[index], ha='center', va='bottom', fontsize=12, weight='bold')
plt.savefig(f"graph_{datasetNames[set_dataset_index]}.png",dpi=500,bbox_inches='tight')
# Out:
# <ipython-input-6-b395a11658dd>:83: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   ax.grid(b=True, which='major', color='gray', linestyle='-', alpha=0.5)
# <ipython-input-6-b395a11658dd>:84: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   ax.grid(b=True, which='minor', color='gray', linestyle='--', alpha=0.2)

# %%
### Now making plots for the alternative diagram

# %%
# Plots for Rebuttal draw for the HM classes
plt.rc('text', usetex=True)
plt.rcParams['text.latex.preamble']=[r"\usepackage{amsmath}"]
benchmarkNames = ['Average', 'Base-to-novel','Domain generalization','Few-shot','Cross-dataset transfer',]
CoOp = [67.16, 71.66 ,59.28, 73.82, 63.88]
CoCoOp = [68.045, 75.83, 59.91, 70.70, 65.74]
PromptSRC = [71.055, 79.97, 60.65 ,77.79, 67]
# Out:
# <ipython-input-33-4cc0eb3c7ade>:3: MatplotlibDeprecationWarning: Support for setting an rcParam that expects a str value to a non-str value is deprecated since 3.5 and support will be removed two minor releases later.
#   plt.rcParams['text.latex.preamble']=[r"\usepackage{amsmath}"]

# %%
N = 4
c = ["tab:blue","sandybrown","white","teal","orangered","tab:purple","tomato","white","slategrey",
     "c","plum","teal","plum","yellowgreen"]
c = ["tab:blue", "sandybrown", "white", "green", "tab:purple"]
ind = np.arange(len(benchmarkNames)) 
width = 0.28
  
fig, ax = plt.subplots(1,1, figsize = (18,6))#extract the labels
label = benchmarkNames

ax.set_ylim([55, 85])


bar1 = ax.bar(ind, CoOp, width, alpha=0.73, color="tab:blue")
  

bar2 = ax.bar(ind+width, CoCoOp, width, alpha=0.73,color="tab:purple")
  

bar3 = ax.bar(ind+width*2, PromptSRC, width,alpha=0.73, color="teal")


# bar4 = ax.bar(ind+width*3, Diversity[0:4], width, color = c[3])

patterns = ('/','//','|','o', '+')
patterns = ('//', '//', '//', '//', '//')
patterns = ('/','//','|','o', '+')
patterns1 = ('|', '|', '|', '|', '|')
patterns2 = ('//', '//', '//', '//', '//')
patterns3 = ('o', 'o', 'o', 'o', 'o')
patterns4 = ('+', '+' ,'+' ,'+', '+')
for bar, pattern in zip(bar1, patterns1):
    bar.set_hatch(pattern)
for bar, pattern in zip(bar2, patterns2):
    bar.set_hatch(pattern)
for bar, pattern in zip(bar3, patterns3):
    bar.set_hatch(pattern)
    
ax.set_axisbelow(True)
ax.grid(b=True, which='major', color='gray', linestyle='-', alpha=0.5)
ax.grid(b=True, which='minor', color='gray', linestyle='--', alpha=0.2)
plt.minorticks_on()
ax.tick_params(axis = "x",
              which = "both",
              labelrotation = 0,
              labelsize = 23)
ax.tick_params(axis = "y",
              which = "both",
              labelsize = 23)

# plt.xlabel("Datasets")
plt.ylabel('Performance (\%)', fontsize = 23)
# plt.title("Players Score")
  
plt.xticks(ind+width,datasetNames)
plt.legend( (bar1, bar2, bar3), ('CoOp', 'CoCoOp', 'PromptSRC'),fontsize=25)

plt.savefig(f"graph_barplot_benchmark.png",dpi=500,bbox_inches='tight')
# Out:
# <ipython-input-48-02d57b9a0117>:40: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   ax.grid(b=True, which='major', color='gray', linestyle='-', alpha=0.5)
# <ipython-input-48-02d57b9a0117>:41: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   ax.grid(b=True, which='minor', color='gray', linestyle='--', alpha=0.2)

# %%
N = 4
c = ["tab:blue","sandybrown","white","teal","orangered","tab:purple","tomato","white","slategrey",
     "c","plum","teal","plum","yellowgreen"]
c = ["tab:blue", "sandybrown", "white", "green", "tab:purple"]
ind = np.arange(len([benchmarkNames[2]])) 
width = 0.1
  
fig, ax = plt.subplots(1,1, figsize = (8,6))#extract the labels
label = benchmarkNames

ax.set_ylim([59, 62])


bar1 = ax.bar(ind, CoOp[2], width, alpha=0.73, color="tab:blue")
  

bar2 = ax.bar(ind+width, CoCoOp[2], width, alpha=0.73,color="tab:purple")
  

bar3 = ax.bar(ind+width*2, PromptSRC[2], width,alpha=0.73, color="teal")


# bar4 = ax.bar(ind+width*3, Diversity[0:4], width, color = c[3])

patterns = ('/','//','|','o', '+')
patterns = ('//', '//', '//', '//', '//')
patterns = ('/','//','|','o', '+')
patterns1 = ('|', '|', '|', '|', '|')
patterns2 = ('//', '//', '//', '//', '//')
patterns3 = ('o', 'o', 'o', 'o', 'o')
patterns4 = ('+', '+' ,'+' ,'+', '+')
for bar, pattern in zip(bar1, patterns1[2]):
    bar.set_hatch(pattern)
for bar, pattern in zip(bar2, patterns2[2]):
    bar.set_hatch(pattern)
for bar, pattern in zip(bar3, patterns3[2]):
    bar.set_hatch(pattern)
    
ax.set_axisbelow(True)
ax.grid(b=True, which='major', color='gray', linestyle='-', alpha=0.5)
ax.grid(b=True, which='minor', color='gray', linestyle='--', alpha=0.2)
plt.minorticks_on()
ax.tick_params(axis = "x",
              which = "both",
              labelrotation = 0,
              labelsize = 23)
ax.tick_params(axis = "y",
              which = "both",
              labelsize = 23)

# plt.xlabel("Datasets")
plt.ylabel('Performance (\%)', fontsize = 23)
# plt.title("Players Score")
  
plt.xticks(ind+width,[datasetNames[2]])
plt.legend( (bar1, bar2, bar3), ('CoOp', 'CoCoOp', 'PromptSRC'),fontsize=20)
# plt.legend( (bar1, bar2, bar3, bar4), ('LSCL', 'GPA', 'Diversity') )
# plt.show()
# plt.savefig(f"graph_barplot_benchmark.png",dpi=500,bbox_inches='tight')
# Out:
# <ipython-input-61-6e1388851452>:40: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   ax.grid(b=True, which='major', color='gray', linestyle='-', alpha=0.5)
# <ipython-input-61-6e1388851452>:41: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   ax.grid(b=True, which='minor', color='gray', linestyle='--', alpha=0.2)

# %%
### Now lets do the same for base-to-novel generalization benchmark
# Plots for Rebuttal draw for the HM classes
plt.rc('text', usetex=True)
plt.rcParams['text.latex.preamble']=[r"\usepackage{amsmath}"]
benchmarkNames = ['Base class performance','Novel class performance','Harmonic Mean (HM)']
CoOp = [82.69 , 63.22 , 71.66 ]
CoCoOp = [80.47 , 71.69 , 75.83 ]
PromptSRC = [84.26 , 76.11 , 79.97 ]
CLIP = [69.34 , 74.22  , 71.71 ]
ProDA = [81.56  ,72.31  , 76.65  ]
# Out:
# <ipython-input-112-b0434d8c55ff>:4: MatplotlibDeprecationWarning: Support for setting an rcParam that expects a str value to a non-str value is deprecated since 3.5 and support will be removed two minor releases later.
#   plt.rcParams['text.latex.preamble']=[r"\usepackage{amsmath}"]

# %%
N = 4
c = ["tab:blue","sandybrown","white","teal","orangered","tab:purple","tomato","white","slategrey",
     "c","plum","teal","plum","yellowgreen"]
c = ["tab:blue", "sandybrown", "white", "green", "tab:purple"]
ind = np.arange(len(benchmarkNames)) 
width = 0.15
print(ind)
fig, ax = plt.subplots(1,1, figsize = (18,6))#extract the labels
label = benchmarkNames

ax.set_ylim([60, 89])


bar1 = ax.bar(ind, CLIP, width, alpha=0.7, color="skyblue")
  

bar2 = ax.bar(ind+width, CoOp, width, alpha=0.73,color="violet")
  

bar3 = ax.bar(ind+width*2, CoCoOp, width,alpha=0.73, color="indianred")

bar4 = ax.bar(ind+width*3, ProDA, width,alpha=0.73, color="forestgreen")

bar5 = ax.bar(ind+width*4, PromptSRC, width,alpha=0.73, color="gold")

# bar4 = ax.bar(ind+width*3, Diversity[0:4], width, color = c[3])

patterns = ('/','//','|','o', '+')
patterns = ('//', '//', '//', '//', '//')
patterns = ('/','//','|','o', '+')
patterns1 = ('o', 'o', 'o', 'o', 'o')
patterns2 = ('|', '|', '|', '|', '|')
patterns3 = ('+', '+' ,'+' ,'+', '+')
patterns4 = ('/', '/' ,'/' ,'/', '/')
patterns5 = ('//', '//', '//', '//', '//')
for bar, pattern in zip(bar1, patterns1):
    bar.set_hatch(pattern)
for bar, pattern in zip(bar2, patterns2):
    bar.set_hatch(pattern)
for bar, pattern in zip(bar3, patterns3):
    bar.set_hatch(pattern)
for bar, pattern in zip(bar4, patterns4):
    bar.set_hatch(pattern)
for bar, pattern in zip(bar5, patterns5):
    bar.set_hatch(pattern)
    
ax.set_axisbelow(True)
ax.grid(b=True, which='major', color='gray', linestyle='-', alpha=0.5)
ax.grid(b=True, which='minor', color='gray', linestyle='--', alpha=0.2)
plt.minorticks_on()
ax.tick_params(axis = "x",
              which = "both",
              labelrotation = 0,
              labelsize = 23)
ax.tick_params(axis = "y",
              which = "both",
              labelsize = 23)

# plt.xlabel("Datasets")
plt.ylabel('Performance (\%)', fontsize = 23)
# plt.title("Players Score")
for bars in ax.containers:
    ax.bar_label(bars,  fontsize = 19, fontweight='bold')
    
plt.xticks(ind+width+0.15,benchmarkNames)
plt.legend( (bar1, bar2, bar3, bar4, bar5), ('CLIP', 'CoOp', 'CoCoOp', 'ProDA', 'PromptSRC (Ours)'),fontsize=20, ncol=3)
# plt.legend( (bar1, bar2, bar3, bar4), ('LSCL', 'GPA', 'Diversity') )
# plt.show()
plt.savefig(f"graph_barplot_base2novel.png",dpi=500,bbox_inches='tight')
# Out:
# [0 1 2]
# <ipython-input-114-fc9f840818a8>:48: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   ax.grid(b=True, which='major', color='gray', linestyle='-', alpha=0.5)
# <ipython-input-114-fc9f840818a8>:49: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   ax.grid(b=True, which='minor', color='gray', linestyle='--', alpha=0.2)

# %%
# Plots for Rebuttal draw for the HM classes
plt.rc('text', usetex=True)
plt.rcParams['text.latex.preamble']=[r"\usepackage{amsmath}"]
benchmarkNames = ['Average', 'Base-to-novel','Domain generalization','Few-shot','Cross-dataset transfer',]
CoOp = [67.16, 71.66 ,59.28, 73.82, 63.88]
CoCoOp = [68.01, 75.83, 59.91, 70.70, 65.74]
PromptSRC = [71.11, 79.97, 60.65 ,77.79, 67]
# Out:
# <ipython-input-117-7d5654e58610>:3: MatplotlibDeprecationWarning: Support for setting an rcParam that expects a str value to a non-str value is deprecated since 3.5 and support will be removed two minor releases later.
#   plt.rcParams['text.latex.preamble']=[r"\usepackage{amsmath}"]

# %%
N = 4
c = ["tab:blue","sandybrown","white","teal","orangered","tab:purple","tomato","white","slategrey",
     "c","plum","teal","plum","yellowgreen"]
c = ["tab:blue", "sandybrown", "white", "green", "tab:purple"]
ind = np.arange(len(benchmarkNames)) 
width = 0.28
  
fig, ax = plt.subplots(1,1, figsize = (18,6))#extract the labels
label = benchmarkNames

ax.set_ylim([55, 85])


bar1 = ax.bar(ind, CoOp, width, alpha=0.73, color="tab:blue")
  

bar2 = ax.bar(ind+width, CoCoOp, width, alpha=0.73,color="tab:purple")
  

bar3 = ax.bar(ind+width*2, PromptSRC, width,alpha=0.73, color="teal")


# bar4 = ax.bar(ind+width*3, Diversity[0:4], width, color = c[3])

patterns = ('/','//','|','o', '+')
patterns = ('//', '//', '//', '//', '//')
patterns = ('/','//','|','o', '+')
patterns1 = ('|', '|', '|', '|', '|')
patterns2 = ('//', '//', '//', '//', '//')
patterns3 = ('o', 'o', 'o', 'o', 'o')
patterns4 = ('+', '+' ,'+' ,'+', '+')
for bar, pattern in zip(bar1, patterns1):
    bar.set_hatch(pattern)
for bar, pattern in zip(bar2, patterns2):
    bar.set_hatch(pattern)
for bar, pattern in zip(bar3, patterns3):
    bar.set_hatch(pattern)
    
ax.set_axisbelow(True)
ax.grid(b=True, which='major', color='gray', linestyle='-', alpha=0.5)
ax.grid(b=True, which='minor', color='gray', linestyle='--', alpha=0.2)
plt.minorticks_on()
ax.tick_params(axis = "x",
              which = "both",
              labelrotation = 0,
              labelsize = 23)
ax.tick_params(axis = "y",
              which = "both",
              labelsize = 23)

# plt.xlabel("Datasets")
plt.ylabel('Performance (\%)', fontsize = 23)
# plt.title("Players Score")
# for bars in ax.containers:
#     ax.bar_label(bars,  fontsize = 17, fontweight='bold')
plt.xticks(ind+width,benchmarkNames)
plt.legend( (bar1, bar2, bar3), ('CoOp', 'CoCoOp', 'PromptSRC'),fontsize=20, ncol=3)

plt.savefig(f"graph_barplot_benchmark.png",dpi=500,bbox_inches='tight')
# Out:
# <ipython-input-89-196eb224a115>:40: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   ax.grid(b=True, which='major', color='gray', linestyle='-', alpha=0.5)
# <ipython-input-89-196eb224a115>:41: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   ax.grid(b=True, which='minor', color='gray', linestyle='--', alpha=0.2)

# %%
fig, ax = plt.subplots(1,1, figsize = (8,6))#extract the labels
label = benchmarkNames
#use this to create x ticks to add the data to
set_dataset_index = 5
x = np.arange(1) #set a width for each bar 
width = 0.02 #create out first bar
#set it so that x will be the centre of the bars
#so that we can add our labels later
#so set the centre of the first to be 1/2 width away
#to the left
x = np.arange(1) #set a width for each bar 
c = ["tab:blue","sandybrown","white","teal","orangered","tab:purple","tomato","white","slategrey",
     "c","plum","teal","plum","yellowgreen"]
c = ["tab:blue", "sandybrown", "white", "green", "tab:purple"]
rect1 = ax.bar(x,
              [CoOp[0]],
              width = width, alpha=0.73, color="tab:blue",
               label = '% classes: MmCoOp is better than CoCoOp',
               edgecolor = "black", align="center"
              )
rect2 = ax.bar(x + width*2,
              [CoCoOp[0]],
              width = width, alpha=0.73, color="tab:purple",
               label = '% classes: MmCoOp is better than CoCoOp',
               edgecolor = "black", align="center"
              )

rect3 = ax.bar(x + width*4,
              [PromptSRC[0]],
              width = width, alpha=0.73, color="teal",
               label = '% classes: MmCoOp is better than CoCoOp',
               edgecolor = "black", align="center"
              )#create the second bar

ax.set_ylim([63, 74.5])

patterns = ('/','//','|','o', '+')
patterns = ('//', '//', '//', '//', '//')
patterns = ('/','//','|','o', '+')
patterns1 = ('|', '|', '|', '|', '|')
patterns2 = ('//', '//', '//', '//', '//')
patterns3 = ('o', 'o', 'o', 'o', 'o')
patterns4 = ('+', '+' ,'+' ,'+', '+')
for bar, pattern in zip(rect1, patterns1):
    bar.set_hatch(pattern)
for bar, pattern in zip(rect2, patterns2):
    bar.set_hatch(pattern)
for bar, pattern in zip(rect3, patterns3):
    bar.set_hatch(pattern)
ax.set_ylabel("Performance (\%)",
             fontsize = 23,
             labelpad = 0, weight='bold')
ax.set_xlabel("Average over 4 benchmarks",
             fontsize = 23,
             labelpad =10, weight='bold')
plt.yticks(fontsize=23,  weight='bold')
ax.set_axisbelow(True)
ax.grid(b=True, which='major', color='gray', linestyle='-', alpha=0.5)
ax.grid(b=True, which='minor', color='gray', linestyle='--', alpha=0.2)
plt.minorticks_on()
for bars in ax.containers:
    ax.bar_label(bars,  fontsize = 19, fontweight='bold')
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off
ax.tick_params(axis = "y",
              which = "both",
              labelsize = 23) 
plt.legend( (rect1, rect2, rect3), ('CoOp', 'CoCoOp', 'PromptSRC (Ours)'),fontsize=20, ncol=1, loc='upper left')
plt.savefig(f"graph_only_average.png",dpi=500,bbox_inches='tight')
# Out:
# <ipython-input-134-350e2bbc55e2>:58: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   ax.grid(b=True, which='major', color='gray', linestyle='-', alpha=0.5)
# <ipython-input-134-350e2bbc55e2>:59: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   ax.grid(b=True, which='minor', color='gray', linestyle='--', alpha=0.2)

# %%
# Plots for Rebuttal draw for the HM classes
plt.rc('text', usetex=True)
plt.rcParams['text.latex.preamble']=[r"\usepackage{amsmath}"]
benchmarkNames = ['Average', 'Base-to-novel','Domain generalization','Few-shot','Cross-dataset transfer',]
CoOp = [67.16, 71.66 ,59.28, 73.82, 63.88]
CoCoOp = [68.01, 75.83, 59.91, 70.70, 65.74]
PromptSRC = [71.11, 79.97, 60.65 ,77.79, 67]
MaPLe = [70.21, 78.55, 60.27, 75.66, 66.30]
# Out:
# /home/gamerx/anaconda3/envs/vclip/lib/python3.7/site-packages/ipykernel_launcher.py:3: MatplotlibDeprecationWarning: Support for setting an rcParam that expects a str value to a non-str value is deprecated since 3.5 and support will be removed two minor releases later.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
fig, ax = plt.subplots(1,1, figsize = (7,6))#extract the labels
label = benchmarkNames
#use this to create x ticks to add the data to
set_dataset_index = 5
x = np.arange(1) #set a width for each bar 
width = 0.02 #create out first bar
#set it so that x will be the centre of the bars
#so that we can add our labels later
#so set the centre of the first to be 1/2 width away
#to the left
x = np.arange(1) #set a width for each bar 
c = ["tab:blue","sandybrown","white","teal","orangered","tab:purple","tomato","white","slategrey",
     "c","plum","teal","plum","yellowgreen"]
c = ["tab:blue", "sandybrown", "white", "green", "tab:purple"]
rect1 = ax.bar(x,
              [CoOp[0]],
              width = width, alpha=0.73, color="tab:blue",
               label = '% classes: MmCoOp is better than CoCoOp',
               edgecolor = "black", align="center"
              )
rect2 = ax.bar(x + width*2,
              [CoCoOp[0]],
              width = width, alpha=0.73, color="tab:purple",
               label = '% classes: MmCoOp is better than CoCoOp',
               edgecolor = "black", align="center"
              )
rect3 = ax.bar(x + width*4,
              [MaPLe[0]],
              width = width, alpha=0.73, color="teal",
               label = '% classes: MmCoOp is better than CoCoOp',
               edgecolor = "black", align="center"
              )#create the second bar

rect4 = ax.bar(x + width*6,
              [PromptSRC[0]],
              width = width, alpha=0.73, color="gold",
               label = '% classes: MmCoOp is better than CoCoOp',
               edgecolor = "black", align="center"
              )#create the second bar



ax.set_ylim([65, 74.5])

patterns1 = ('|', '|', '|', '|', '|')
patterns2 = ('//', '//', '//', '//', '//')
patterns3 = ('o', 'o', 'o', 'o', 'o')
patterns4 = ('+', '+' ,'+' ,'+', '+')
for bar, pattern in zip(rect1, patterns1):
    bar.set_hatch(pattern)
for bar, pattern in zip(rect2, patterns2):
    bar.set_hatch(pattern)
for bar, pattern in zip(rect3, patterns4):
    bar.set_hatch(pattern)
for bar, pattern in zip(rect4, patterns3):
    bar.set_hatch(pattern)
ax.set_ylabel("Performance (\%)",
             fontsize = 23,
             labelpad = 0, weight='bold')
ax.set_xlabel("Average over 4 benchmarks",
             fontsize = 23,
             labelpad =10, weight='bold')
plt.yticks(fontsize=23,  weight='bold')
ax.set_axisbelow(True)
ax.grid(b=True, which='major', color='gray', linestyle='-', alpha=0.5)
ax.grid(b=True, which='minor', color='gray', linestyle='--', alpha=0.2)
plt.minorticks_on()
for bars in ax.containers:
    ax.bar_label(bars,  fontsize = 19, fontweight='bold')
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off
ax.tick_params(axis = "y",
              which = "both",
              labelsize = 23) 
plt.legend( (rect1, rect2, rect3, rect4), ('CoOp', 'CoCoOp', 'MaPLe', 'PromptSRC (Ours)'),fontsize=20, ncol=1, loc='upper left')
# plt.savefig(f"graph_only_average_new.png",dpi=500,bbox_inches='tight')
# Out:
# /home/gamerx/anaconda3/envs/vclip/lib/python3.7/site-packages/ipykernel_launcher.py:65: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
# /home/gamerx/anaconda3/envs/vclip/lib/python3.7/site-packages/ipykernel_launcher.py:66: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.

# %%
### Now lets do the same for base-to-novel generalization benchmark
# Plots for Rebuttal draw for the HM classes
plt.rc('text', usetex=True)
plt.rcParams['text.latex.preamble']=[r"\usepackage{amsmath}"]
benchmarkNames = ['Base class performance','Novel class performance','Harmonic Mean (HM)']
CoOp = [82.69 , 63.22 , 71.66 ]
CoCoOp = [80.47 , 71.69 , 75.83 ]
PromptSRC = [84.26 , 76.11 , 79.97 ]
CLIP = [69.34 , 74.22  , 71.71 ]
ProDA = [81.56  ,72.31  , 76.65]
MaPLe = [82.28, 75.14, 78.55]
# Out:
# /home/gamerx/anaconda3/envs/vclip/lib/python3.7/site-packages/ipykernel_launcher.py:4: MatplotlibDeprecationWarning: Support for setting an rcParam that expects a str value to a non-str value is deprecated since 3.5 and support will be removed two minor releases later.
#   after removing the cwd from sys.path.

# %%
N = 4
c = ["tab:blue","sandybrown","white","teal","orangered","tab:purple","tomato","white","slategrey",
     "c","plum","teal","plum","yellowgreen"]
c = ["tab:blue", "sandybrown", "white", "green", "tab:purple"]
ind = np.arange(len(benchmarkNames)) 
width = 0.15
print(ind)
fig, ax = plt.subplots(1,1, figsize = (18,6))#extract the labels
label = benchmarkNames

ax.set_ylim([62, 88])


bar1 = ax.bar(ind, CLIP, width, alpha=0.7, color="skyblue")
  

bar2 = ax.bar(ind+width, CoOp, width, alpha=0.73,color="violet")
  

bar3 = ax.bar(ind+width*2, CoCoOp, width,alpha=0.73, color="indianred")

bar4 = ax.bar(ind+width*3, ProDA, width,alpha=0.73, color="forestgreen")

bar5 = ax.bar(ind+width*4, MaPLe, width,alpha=0.73, color="teal")

bar6 = ax.bar(ind+width*5, PromptSRC, width,alpha=0.73, color="gold")

# bar4 = ax.bar(ind+width*3, Diversity[0:4], width, color = c[3])

patterns1 = ('\\', '\\', '\\', '\\', '\\')
patterns2 = ('|', '|', '|', '|', '|')
patterns3 = ('/', '/' ,'/' ,'/', '/')
patterns4 = ('//', '//', '//', '//', '//')
patterns5 = ('+', '+' ,'+' ,'+', '+')
patterns6 = ('o', 'o', 'o', 'o', 'o')

# patterns5 = ('//', '//', '//', '//', '//')
for bar, pattern in zip(bar1, patterns1):
    bar.set_hatch(pattern)
for bar, pattern in zip(bar2, patterns2):
    bar.set_hatch(pattern)
for bar, pattern in zip(bar3, patterns3):
    bar.set_hatch(pattern)
for bar, pattern in zip(bar4, patterns4):
    bar.set_hatch(pattern)
for bar, pattern in zip(bar5, patterns5):
    bar.set_hatch(pattern)
for bar, pattern in zip(bar6, patterns6):
    bar.set_hatch(pattern)
    
ax.set_axisbelow(True)
ax.grid(b=True, which='major', color='gray', linestyle='-', alpha=0.5)
ax.grid(b=True, which='minor', color='gray', linestyle='--', alpha=0.2)
plt.minorticks_on()
ax.tick_params(axis = "x",
              which = "both",
              labelrotation = 0,
              labelsize = 23)
ax.tick_params(axis = "y",
              which = "both",
              labelsize = 23)

# plt.xlabel("Datasets")
plt.ylabel('Performance (\%)', fontsize = 23)
# plt.title("Players Score")
for bars in ax.containers:
    ax.bar_label(bars,  fontsize = 19, fontweight='bold')
    
plt.xticks(ind+width+0.15,benchmarkNames)
plt.legend( (bar1, bar2, bar3, bar4, bar5, bar6), ('CLIP', 'CoOp', 'CoCoOp', 'ProDA','MaPLe', 'PromptSRC (Ours)'),fontsize=20, ncol=3)
# plt.legend( (bar1, bar2, bar3, bar4), ('LSCL', 'GPA', 'Diversity') )
# plt.show()
plt.savefig(f"graph_barplot_base2novel_new.png",dpi=500,bbox_inches='tight')
# Out:
# [0 1 2]
# /home/gamerx/anaconda3/envs/vclip/lib/python3.7/site-packages/ipykernel_launcher.py:52: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
# /home/gamerx/anaconda3/envs/vclip/lib/python3.7/site-packages/ipykernel_launcher.py:53: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import sys
from pathlib import Path
from matplotlib import pyplot as plt
import matplotlib.font_manager as font_manager

# %%
# Plots for Rebuttal draw for the HM classes
plt.rc('text', usetex=True)
plt.rcParams['text.latex.preamble']=[r"\usepackage{amsmath}"]
benchmarkNames = ['Average', 'Base-to-novel','Domain generalization','Few-shot','Cross-dataset transfer',]
CoOp = [67.16, 71.66 ,59.28, 73.82, 63.88]
CoCoOp = [68.01, 75.83, 59.91, 70.70, 65.74]
PromptSRC = [71.11, 79.97, 60.65 ,77.79, 65.81]
MaPLe = [70.21, 78.55, 60.27, 75.66, 66.30]
CLIP = [65.15]
ProText = [67.23]
CUPL = []
# Out:
# /home/gamerx/anaconda3/envs/vclip/lib/python3.7/site-packages/ipykernel_launcher.py:3: MatplotlibDeprecationWarning: Support for setting an rcParam that expects a str value to a non-str value is deprecated since 3.5 and support will be removed two minor releases later.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
fig, ax = plt.subplots(1,1, figsize = (12,6))#extract the labels
label = benchmarkNames
#use this to create x ticks to add the data to
set_dataset_index = 5
x = np.arange(1) #set a width for each bar 
width = 0.02 #create out first bar
#set it so that x will be the centre of the bars
#so that we can add our labels later
#so set the centre of the first to be 1/2 width away
#to the left
x = np.arange(1) #set a width for each bar 
c = ["tab:blue","sandybrown","white","teal","orangered","tab:purple","tomato","white","slategrey",
     "c","plum","teal","plum","yellowgreen"]
c = ["tab:blue", "sandybrown", "white", "green", "tab:purple"]

rect1 = ax.bar(x,
              [CLIP[-1]],
              width = width, alpha=0.73, color="violet",
               label = '% classes: MmCoOp is better than CoCoOp',
               edgecolor = "black", align="center"
              )#create the second bar

rect2 = ax.bar(x + width*2,
              [CoOp[-1]],
              width = width, alpha=0.73, color="tab:blue",
               label = '% classes: MmCoOp is better than CoCoOp',
               edgecolor = "black", align="center"
              )
rect3 = ax.bar(x + width*4,
              [CoCoOp[-1]],
              width = width, alpha=0.73, color="tab:purple",
               label = '% classes: MmCoOp is better than CoCoOp',
               edgecolor = "black", align="center"
              )

rect4 = ax.bar(x + width*6,
              [PromptSRC[-1]],
              width = width, alpha=0.73, color="indianred",
               label = '% classes: MmCoOp is better than CoCoOp',
               edgecolor = "black", align="center"
              )#create the second bar


rect5 = ax.bar(x + width*8,
              [MaPLe[-1]],
              width = width, alpha=0.73, color="skyblue",
               label = '% classes: MmCoOp is better than CoCoOp',
               edgecolor = "black", align="center"
              )#create the second bar

rect6 = ax.bar(x + width*10,
              [ProText[-1]],
              width = width, alpha=0.73, color="gold",
               label = '% classes: MmCoOp is better than CoCoOp',
               edgecolor = "black", align="center"
              )#create the second bar

ax.set_ylim([63, 68.5])

patterns1 = ('\\', '\\', '\\', '\\', '\\')
patterns2 = ('|', '|', '|', '|', '|')
patterns3 = ('/', '/' ,'/' ,'/', '/')
patterns4 = ('//', '//', '//', '//', '//')
patterns5 = ('+', '+' ,'+' ,'+', '+')
patterns6 = ('o', 'o', 'o', 'o', 'o')

# patterns5 = ('//', '//', '//', '//', '//')
for bar, pattern in zip(rect1, patterns1):
    bar.set_hatch(pattern)
for bar, pattern in zip(rect2, patterns2):
    bar.set_hatch(pattern)
for bar, pattern in zip(rect3, patterns3):
    bar.set_hatch(pattern)
for bar, pattern in zip(rect4, patterns4):
    bar.set_hatch(pattern)
for bar, pattern in zip(rect5, patterns5):
    bar.set_hatch(pattern)
for bar, pattern in zip(rect6, patterns6):
    bar.set_hatch(pattern)
    
    
ax.set_ylabel("Performance (\%)",
             fontsize = 23,
             labelpad = 0, weight='bold')
ax.set_xlabel("Average over 10 datasets",
             fontsize = 23,
             labelpad =10, weight='bold')
plt.yticks(fontsize=23,  weight='bold')
ax.set_axisbelow(True)
ax.grid(b=True, which='major', color='gray', linestyle='-', alpha=0.5)
ax.grid(b=True, which='minor', color='gray', linestyle='--', alpha=0.2)
plt.minorticks_on()
for bars in ax.containers:
    ax.bar_label(bars,  fontsize = 19, fontweight='bold')
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off
ax.tick_params(axis = "y",
              which = "both",
              labelsize = 23) 
plt.legend( (rect1, rect2, rect3, rect4, rect5, rect6), ('CLIP', 'CoOp', 'CoCoOp', 'PromptSRC', 'MaPLe', "ProText (Ours)"),fontsize=20, ncol=2, loc='upper left')
# plt.savefig(f"graph_only_average_new.pdf",dpi=500,bbox_inches='tight')
# Out:
# /home/gamerx/anaconda3/envs/vclip/lib/python3.7/site-packages/ipykernel_launcher.py:90: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
# /home/gamerx/anaconda3/envs/vclip/lib/python3.7/site-packages/ipykernel_launcher.py:91: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.

# %%
fig, ax = plt.subplots(1,1, figsize = (14,6))#extract the labels
label = benchmarkNames
#use this to create x ticks to add the data to
set_dataset_index = 5
x = np.arange(1) #set a width for each bar 
width = 0.02 #create out first bar
#set it so that x will be the centre of the bars
#so that we can add our labels later
#so set the centre of the first to be 1/2 width away
#to the left
x = np.arange(1) #set a width for each bar 
c = ["tab:blue","sandybrown","white","teal","orangered","tab:purple","tomato","white","slategrey",
     "c","plum","teal","plum","yellowgreen"]
c = ["tab:blue", "sandybrown", "white", "green", "tab:purple"]

rect1 = ax.bar(x,
              [CLIP[-1]],
              width = width, alpha=0.73, color="violet",
               label = '% classes: MmCoOp is better than CoCoOp',
               edgecolor = "black", align="center"
              )#create the second bar

rect2 = ax.bar(x + width*2,
              [CLIP[-1]],
              width = width, alpha=0.73, color="yellowgreen",
               label = '% classes: MmCoOp is better than CoCoOp',
               edgecolor = "black", align="center"
              )#create the second bar

rect3 = ax.bar(x + width*4,
              [CoOp[-1]],
              width = width, alpha=0.73, color="tab:blue",
               label = '% classes: MmCoOp is better than CoCoOp',
               edgecolor = "black", align="center"
              )
rect4 = ax.bar(x + width*6,
              [CoCoOp[-1]],
              width = width, alpha=0.73, color="tab:purple",
               label = '% classes: MmCoOp is better than CoCoOp',
               edgecolor = "black", align="center"
              )

rect5 = ax.bar(x + width*8,
              [PromptSRC[-1]],
              width = width, alpha=0.73, color="indianred",
               label = '% classes: MmCoOp is better than CoCoOp',
               edgecolor = "black", align="center"
              )#create the second bar


rect6 = ax.bar(x + width*10,
              [MaPLe[-1]],
              width = width, alpha=0.73, color="skyblue",
               label = '% classes: MmCoOp is better than CoCoOp',
               edgecolor = "black", align="center"
              )#create the second bar

rect7 = ax.bar(x + width*12,
              [ProText[-1]],
              width = width, alpha=0.73, color="gold",
               label = '% classes: MmCoOp is better than CoCoOp',
               edgecolor = "black", align="center"
              )#create the second bar

ax.set_ylim([63, 68.5])

patterns1 = ('\\', '\\', '\\', '\\', '\\')
patterns2 = ('||', '||', '||', '||', '||')
patterns3 = ('|', '|', '|', '|', '|')
patterns4 = ('/', '/' ,'/' ,'/', '/')
patterns5 = ('//', '//', '//', '//', '//')
patterns6 = ('+', '+' ,'+' ,'+', '+')
patterns7 = ('o', 'o', 'o', 'o', 'o')
# patterns5 = ('//', '//', '//', '//', '//')
for bar, pattern in zip(rect1, patterns1):
    bar.set_hatch(pattern)
for bar, pattern in zip(rect2, patterns2):
    bar.set_hatch(pattern)
for bar, pattern in zip(rect3, patterns3):
    bar.set_hatch(pattern)
for bar, pattern in zip(rect4, patterns4):
    bar.set_hatch(pattern)
for bar, pattern in zip(rect5, patterns5):
    bar.set_hatch(pattern)
for bar, pattern in zip(rect6, patterns6):
    bar.set_hatch(pattern)
for bar, pattern in zip(rect7, patterns7):
    bar.set_hatch(pattern)
    
    
ax.set_ylabel("Performance (\%)",
             fontsize = 26,
             labelpad = 0, weight='bold')
ax.set_xlabel("Average over 10 datasets",
             fontsize = 28,
             labelpad =10, weight='bold')
plt.yticks(fontsize=23,  weight='bold')
ax.set_axisbelow(True)
ax.grid(b=True, which='major', color='gray', linestyle='-', alpha=0.5)
ax.grid(b=True, which='minor', color='gray', linestyle='--', alpha=0.2)
plt.minorticks_on()
for bars in ax.containers:
    ax.bar_label(bars,  fontsize = 22, fontweight='bold')
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off
ax.tick_params(axis = "y",
              which = "both",
              labelsize = 24) 
plt.legend( (rect1, rect2, rect3, rect4, rect5, rect6, rect7), ('CLIP', 'CuPL', 'CoOp', 'CoCoOp', 'PromptSRC', 'MaPLe', 'ProText (Ours)'),fontsize=22.2, ncol=3, loc='upper left')
plt.savefig(f"cupl_added.pdf",dpi=500,bbox_inches='tight')
# Out:
# /home/gamerx/anaconda3/envs/vclip/lib/python3.7/site-packages/ipykernel_launcher.py:99: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
# /home/gamerx/anaconda3/envs/vclip/lib/python3.7/site-packages/ipykernel_launcher.py:100: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.

# %%
# Plots for Rebuttal draw for the HM classes
# plt.rc('text', usetex=True)
# plt.rcParams['text.latex.preamble']=[r"\usepackage{amsmath}"]
benchmarkNames = ['Average', 'Base-to-novel','Domain generalization','Few-shot','Cross-dataset transfer',]
CoOp = [69.62, 71.66 ,59.28, 73.82, 63.88]
CoCoOp = [69.96, 75.83, 59.91, 70.70, 65.74]
PromptSRC = [70.22, 79.97, 60.65 ,77.79, 67]

# %%
fig, ax = plt.subplots(1,1, figsize = (7,6))#extract the labels
label = benchmarkNames
#use this to create x ticks to add the data to
set_dataset_index = 5
x = np.arange(1) #set a width for each bar 
width = 0.02 #create out first bar
#set it so that x will be the centre of the bars
#so that we can add our labels later
#so set the centre of the first to be 1/2 width away
#to the left
x = np.arange(1) #set a width for each bar 
c = ["tab:blue","sandybrown","white","teal","orangered","tab:purple","tomato","white","slategrey",
     "c","plum","teal","plum","yellowgreen"]
c = ["tab:blue", "sandybrown", "white", "green", "tab:purple"]
rect1 = ax.bar(x,
              [CoOp[0]],
              width = width, alpha=0.73, color="tab:blue",
               label = '% classes: MmCoOp is better than CoCoOp',
               edgecolor = "black", align="center"
              )
rect2 = ax.bar(x + width*2,
              [CoCoOp[0]],
              width = width, alpha=0.73, color="tab:purple",
               label = '% classes: MmCoOp is better than CoCoOp',
               edgecolor = "black", align="center"
              )

rect3 = ax.bar(x + width*4,
              [PromptSRC[0]],
              width = width, alpha=0.73, color="teal",
               label = '% classes: MmCoOp is better than CoCoOp',
               edgecolor = "black", align="center"
              )#create the second bar

ax.set_ylim([68.7, 70.6])

patterns = ('/','//','|','o', '+')
patterns = ('//', '//', '//', '//', '//')
patterns = ('/','//','|','o', '+')
patterns1 = ('|', '|', '|', '|', '|')
patterns2 = ('//', '//', '//', '//', '//')
patterns3 = ('o', 'o', 'o', 'o', 'o')
patterns4 = ('+', '+' ,'+' ,'+', '+')
for bar, pattern in zip(rect1, patterns1):
    bar.set_hatch(pattern)
for bar, pattern in zip(rect2, patterns2):
    bar.set_hatch(pattern)
for bar, pattern in zip(rect3, patterns3):
    bar.set_hatch(pattern)
ax.set_ylabel("ImageNet Top-1 Acc.",
             fontsize = 26,
             labelpad = 0)
# ax.set_xlabel("Average over 4 benchmarks",
#              fontsize = 23,
#              labelpad =10)
plt.yticks(fontsize=23)
plt.xticks([0, width*2, width*4], ['CuPL', 'ProText\nEnsembled', 'ProText'],fontsize=23)
ax.set_axisbelow(True)
ax.grid(b=True, which='major', color='gray', linestyle='-', alpha=0.5)
ax.grid(b=True, which='minor', color='gray', linestyle='--', alpha=0.2)
plt.minorticks_on()
# plt.tick_params(
#     axis='x',          # changes apply to the x-axis
#     which='both',      # both major and minor ticks are affected
#     bottom=False,      # ticks along the bottom edge are off
#     top=False,         # ticks along the top edge are off
#     labelbottom=False) # labels along the bottom edge are off
ax.tick_params(axis = "y",
              which = "both",
              labelsize = 23) 
# plt.legend( (rect1, rect2, rect3), ('CuPL', 'ProText-Ensembled', 'ProText'),fontsize=20, ncol=1, loc='upper left')
plt.savefig(f"ablation_on_ensembled_text_supervision.png",dpi=500,bbox_inches='tight')
# Out:
# /home/gamerx/anaconda3/envs/vclip/lib/python3.7/site-packages/ipykernel_launcher.py:59: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
# /home/gamerx/anaconda3/envs/vclip/lib/python3.7/site-packages/ipykernel_launcher.py:60: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
